# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
dispo_alimentaire = pd.read_csv('data/dispo_alimentaire.csv')
dispo_alimentaire.head()
# Out:
#           Zone                Produit   Origine  Aliments pour animaux  \
# 0  Afghanistan       Abats Comestible   animale                    NaN
# 1  Afghanistan        Agrumes, Autres  vegetale                    NaN
# 2  Afghanistan  Aliments pour enfants  vegetale                    NaN
# 3  Afghanistan                 Ananas  vegetale                    NaN
# 4  Afghanistan                Bananes  vegetale                    NaN
#
#    Autres Utilisations  Disponibilité alimentaire (Kcal/personne/jour)  \
# 0                  NaN                                             5.0
# 1                  NaN                                             1.0
# 2                  NaN                                             1.0
# 3                  NaN                                             0.0
# 4                  NaN                                             4.0
#
#    Disponibilité alimentaire en quantité (kg/personne/an)  \
# 0                                               1.72
# 1                                               1.29
# 2                                               0.06
# 3                                               0.00
# 4                                               2.70
#
#    Disponibilité de matière grasse en quantité (g/personne/jour)  \
# 0                                               0.20
# 1                                               0.01
# 2                                               0.01
# 3                                                NaN
# 4                                               0.02
#
#    Disponibilité de protéines en quantité (g/personne/jour)  \
# 0                                               0.77
# 1                                               0.02
# 2                                               0.03
# 3                                                NaN
# 4                                               0.05
#
#    Disponibilité intérieure  Exportations - Quantité  Importations - Quantité  \
# 0                      53.0                      NaN                      NaN
# 1                      41.0                      2.0                     40.0
# 2                       2.0                      NaN                      2.0
# 3                       0.0                      NaN                      0.0
# 4                      82.0                      NaN                     82.0
#
#    Nourriture  Pertes  Production  Semences  Traitement  Variation de stock
# 0        53.0     NaN        53.0       NaN         NaN                 NaN
# 1        39.0     2.0         3.0       NaN         NaN                 NaN
# 2         2.0     NaN         NaN       NaN         NaN                 NaN
# 3         0.0     NaN         NaN       NaN         NaN                 NaN
# 4        82.0     NaN         NaN       NaN         NaN                 NaN

# %%
# suppression des NaN
dispo_alimentaire = dispo_alimentaire.dropna()

# %%
aide_alimentaire = pd.read_csv('data/aide_alimentaire.csv')
aide_alimentaire.head()
# Out:
#   Pays bénéficiaire  Année              Produit  Valeur
# 0       Afghanistan   2013  Autres non-céréales     682
# 1       Afghanistan   2014  Autres non-céréales     335
# 2       Afghanistan   2013         Blé et Farin   39224
# 3       Afghanistan   2014         Blé et Farin   15160
# 4       Afghanistan   2013             Céréales   40504

# %%
aide_alimentaire.info()
print("-------------------------------")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1475 entries, 0 to 1474
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Pays bénéficiaire  1475 non-null   object
#  1   Année              1475 non-null   int64
#  2   Produit            1475 non-null   object
#  3   Valeur             1475 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 46.2+ KB
# -------------------------------

# %%
population = pd.read_csv('data/population.csv')
population.head()
# Out:
#           Zone  Année     Valeur
# 0  Afghanistan   2013  32269.589
# 1  Afghanistan   2014  33370.794
# 2  Afghanistan   2015  34413.603
# 3  Afghanistan   2016  35383.032
# 4  Afghanistan   2017  36296.113

# %%
population.info()
print("-------------------------------")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1416 entries, 0 to 1415
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Zone    1416 non-null   object
#  1   Année   1416 non-null   int64
#  2   Valeur  1416 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 33.3+ KB
# -------------------------------

# %%
sous_nutrition = pd.read_csv('data/sous_nutrition.csv')
sous_nutrition.head()
# Out:
#           Zone      Année Valeur
# 0  Afghanistan  2012-2014    8.6
# 1  Afghanistan  2013-2015    8.8
# 2  Afghanistan  2014-2016    8.9
# 3  Afghanistan  2015-2017    9.7
# 4  Afghanistan  2016-2018   10.5

# %%
sous_nutrition["Année"] = sous_nutrition["Année"].map({'2012-2014': 2013,
                                                       '2013-2015': 2014,
                                                       '2014-2016': 2015,
                                                       '2015-2017': 2016,
                                                       '2016-2018': 2017,
                                                       '2017-2019': 2018})

# %%
# suppression des NaN
sous_nutrition = sous_nutrition.dropna()

# %%
sous_nutrition['Valeur'] = sous_nutrition['Valeur'].astype(str)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.8.12/envs/simplon/lib/python3.8/site-packages/pandas/core/indexes/base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File ~/.pyenv/versions/3.8.12/envs/simplon/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.pyenv/versions/3.8.12/envs/simplon/lib/python3.8/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Valeur'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [40], line 1
# ----> 1 sous_nutrition['Valeur'] = sous_nutrition['Valeur'].astype(str)
#
# File ~/.pyenv/versions/3.8.12/envs/simplon/lib/python3.8/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/.pyenv/versions/3.8.12/envs/simplon/lib/python3.8/site-packages/pandas/core/indexes/base.py:3631, in Index.get_loc(self, key, method, tolerance)
#    3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
# -> 3631     raise KeyError(key) from err
#    3632 except TypeError:
#    3633     # If we have a listlike key, _check_indexing_error will raise
#    3634     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3635     #  the TypeError.
#    3636     self._check_indexing_error(key)
#
# KeyError: 'Valeur'

# %%
sous_nutrition.head()
# Out:
#           Zone  Année Valeur
# 0  Afghanistan   2013    8.6
# 1  Afghanistan   2014    8.8
# 2  Afghanistan   2015    8.9
# 3  Afghanistan   2016    9.7
# 4  Afghanistan   2017   10.5

# %%
sous_nutrition.info()
print("-------------------------------")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 624 entries, 0 to 1199
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Zone    624 non-null    object
#  1   Année   624 non-null    int64
#  2   Valeur  624 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 19.5+ KB
# -------------------------------

# %%
# Changement des noms de colonnes

aide_alimentaire = aide_alimentaire.rename(columns = {'Pays bénéficiaire': 'Zone', 'Valeur': 'Quantité (en tonne)'})
sous_nutrition = sous_nutrition.rename(columns = {'Valeur': 'sous_nutrition (million)'})
population = population.rename(columns = {'Valeur': 'nb_population (millier)'})

# %%
def merge_année(année=str):
    aide_alimentaire["Année"] = aide_alimentaire["Année"].astype(str)
    d1 = aide_alimentaire[aide_alimentaire["Année"] == année]
    sous_nutrition["Année"] = sous_nutrition["Année"].astype(str)
    d2 = sous_nutrition[sous_nutrition["Année"] == année]
    population["Année"] = population["Année"].astype(str)
    d3 = population[population["Année"] == année]
    ano = d1.merge(d2, on = "Zone", how = "left")
    result = ano.merge(d3, on = "Zone", how = "left")
    result["nb_population (million)"] = round((result["nb_population (millier)"]/1000),2)
    result['rapport_nutritionnel (tonne/habitant)'] = round((result["Quantité (en tonne)"] / result["nb_population (million)"]),2)
    result = result.dropna()
    nutri = result.groupby("Zone", axis = 0).min()
    fig, ax = plt.subplots(1,2, figsize = (12,8))
    sns.barplot(data = nutri.sort_values("rapport_nutritionnel (tonne/habitant)", ascending = False).head(5),\
                     y = "rapport_nutritionnel (tonne/habitant)", x = "nb_population (million)", ax = ax[0])

    plt.title('Top 5 des pays en ratio alimentaire')
    sns.barplot(data= nutri.sort_values("rapport_nutritionnel (tonne/habitant)", ascending = True).head(5),\
                     y = "rapport_nutritionnel (tonne/habitant)", x = "nb_population (million)", ax = ax[1])
    plt.title('Flop 5 des pays en ratio alimentaire')
    fig.show()
    return nutri

# %%
tt = merge_année("2013")
tt
# Out:
#                                            Année_x              Produit  \
# Zone
# Afghanistan                                   2013  Autres non-céréales
# Algérie                                       2013  Autres non-céréales
# Angola                                        2013             Céréales
# Bangladesh                                    2013         Blé et Farin
# Burkina Faso                                  2013  Autres non-céréales
# Bénin                                         2013  Autres non-céréales
# Cambodge                                      2013  Autres non-céréales
# Cameroun                                      2013  Autres non-céréales
# Colombie                                      2013             Céréales
# Congo                                         2013  Autres non-céréales
# Côte d'Ivoire                                 2013  Autres non-céréales
# El Salvador                                   2013             Céréales
# Gambie                                        2013             Céréales
# Ghana                                         2013             Céréales
# Guatemala                                     2013             Céréales
# Géorgie                                       2013  Autres non-céréales
# Haïti                                         2013  Autres non-céréales
# Honduras                                      2013             Céréales
# Iran (République islamique d')                2013             Céréales
# Iraq                                          2013  Autres non-céréales
# Jordanie                                      2013  Autres non-céréales
# Kenya                                         2013         Blé et Farin
# Kirghizistan                                  2013         Blé et Farin
# Lesotho                                       2013             Céréales
# Liban                                         2013  Autres non-céréales
# Libéria                                       2013  Autres non-céréales
# Madagascar                                    2013  Autres non-céréales
# Malawi                                        2013  Autres non-céréales
# Mali                                          2013  Autres non-céréales
# Mauritanie                                    2013  Autres non-céréales
# Mozambique                                    2013             Céréales
# Myanmar                                       2013             Céréales
# Nicaragua                                     2013  Autres non-céréales
# Népal                                         2013             Céréales
# Pakistan                                      2013  Autres non-céréales
# Philippines                                   2013  Autres non-céréales
# Rwanda                                        2013             Céréales
# République dominicaine                        2013  Autres non-céréales
# République populaire démocratique de Corée    2013         Blé et Farin
# République-Unie de Tanzanie                   2013         Blé et Farin
# Sao Tomé-et-Principe                          2013             Céréales
# Sierra Leone                                  2013         BulgurFarEnt
# Soudan                                        2013             Céréales
# Sri Lanka                                     2013             Céréales
# Sénégal                                       2013  Autres non-céréales
# Tchad                                         2013  Autres non-céréales
# Timor-Leste                                   2013             Céréales
# Togo                                          2013  Autres non-céréales
# Égypte                                        2013   Fruits secs, total
# Équateur                                      2013             Céréales
# Éthiopie                                      2013  Autres non-céréales
#
#                                             Quantité (en tonne) Année_y  \
# Zone
#                                             rapport_nutritionnel (tonne/habitant)
# Zone
# Afghanistan                                                                  2.63
# Algérie                                                                      5.35
# Angola                                                                      96.08
# Bangladesh                                                                   0.53
# Burkina Faso                                                                 0.59
# Bénin                                                                        4.50
# Cambodge                                                                     3.33
# Cameroun                                                                     5.30
# Colombie                                                                     2.97
# Congo                                                                        3.90
# Côte d'Ivoire                                                                3.03
# El Salvador                                                                160.29
# Gambie                                                                     177.04
# Ghana                                                                       12.10
# Guatemala                                                                   76.22
# Géorgie                                                                      0.25
# Haïti                                                                        1.63
# Honduras                                                                   317.95
# Iran (République islamique d')                                               0.60
# Iraq                                                                         0.12
# Jordanie                                                                     0.35
# Kenya                                                                        1.01
# Kirghizistan                                                                13.96
# Lesotho                                                                     39.90
# Liban                                                                        0.34
# Libéria                                                                      0.47
# Madagascar                                                                   0.22
# Malawi                                                                       3.98
# Mali                                                                        51.85
# Mauritanie                                                                  23.30
# Mozambique                                                                  19.72
# Myanmar                                                                     13.77
# Nicaragua                                                                   22.44
# Népal                                                                        2.38
# Pakistan                                                                     0.05
# Philippines                                                                  1.10
# Rwanda                                                                      45.98
# République dominicaine                                                       1.19
# République populaire démocratique de Corée                                  36.10
# République-Unie de Tanzanie                                                  3.16
# Sao Tomé-et-Principe                                                       189.47
# Sierra Leone                                                                34.99
# Soudan                                                                       1.24
# Sri Lanka                                                                    0.05
# Sénégal                                                                     24.09
# Tchad                                                                        0.00
# Timor-Leste                                                                 19.13
# Togo                                                                         0.29
# Égypte                                                                       6.35
# Équateur                                                                     6.56
# Éthiopie                                                                     1.78

# %%
top = tt.head(5)
top
# Out:
#                      Année_x   Produit  Quantité (en tonne) Année_y  \
# Zone
# Honduras                2013  Céréales                 2798    2013
# Sao Tomé-et-Principe    2013  Céréales                   36    2013
# Gambie                  2013  Céréales                  347    2013
# El Salvador             2013  Céréales                 1005    2013
# Angola                  2013  Céréales                 2500    2013
#
#                      sous_nutrition (million) Année  nb_population (millier)  \
# Zone
# Honduras                                  1.7  2013                 8798.521
# Sao Tomé-et-Principe                     <0.1  2013                  192.087
# Gambie                                    0.2  2013                 1963.712
# El Salvador                               0.7  2013                 6266.070
# Angola                                    7.6  2013                26015.781
#
#                       nb_population (million)  \
# Zone
# Honduras                                 8.80
# Sao Tomé-et-Principe                     0.19
# Gambie                                   1.96
# El Salvador                              6.27
# Angola                                  26.02
#
#                       rapport_nutritionnel (tonne/habitant)
# Zone
# Honduras                                             317.95
# Sao Tomé-et-Principe                                 189.47
# Gambie                                               177.04
# El Salvador                                          160.29
# Angola                                                96.08

# %%
top.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, Honduras to Angola
# Data columns (total 9 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Année_x                                5 non-null      object
#  1   Produit                                5 non-null      object
#  2   Quantité (en tonne)                    5 non-null      int64
#  3   Année_y                                5 non-null      object
#  4   sous_nutrition (million)               5 non-null      object
#  5   Année                                  5 non-null      object
#  6   nb_population (millier)                5 non-null      float64
#  7   nb_population (million)                5 non-null      float64
#  8   rapport_nutritionnel (tonne/habitant)  5 non-null      float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 400.0+ bytes

# %%
    top5 = sns.barplot(data = nutri.sort_values("rapport_nutritionnel (tonne/habitant)", ascending = False).head(5),\
                     y = "rapport_nutritionnel (tonne/habitant)", x = "nb_population (million)")
