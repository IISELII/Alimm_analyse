# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
dispo_alimentaire = pd.read_csv('data/dispo_alimentaire.csv')
dispo_alimentaire.head()
# Out:
#           Zone                Produit   Origine  Aliments pour animaux  \
# 0  Afghanistan       Abats Comestible   animale                    NaN
# 1  Afghanistan        Agrumes, Autres  vegetale                    NaN
# 2  Afghanistan  Aliments pour enfants  vegetale                    NaN
# 3  Afghanistan                 Ananas  vegetale                    NaN
# 4  Afghanistan                Bananes  vegetale                    NaN
#
#    Autres Utilisations  Disponibilité alimentaire (Kcal/personne/jour)  \
# 0                  NaN                                             5.0
# 1                  NaN                                             1.0
# 2                  NaN                                             1.0
# 3                  NaN                                             0.0
# 4                  NaN                                             4.0
#
#    Disponibilité alimentaire en quantité (kg/personne/an)  \
# 0                                               1.72
# 1                                               1.29
# 2                                               0.06
# 3                                               0.00
# 4                                               2.70
#
#    Disponibilité de matière grasse en quantité (g/personne/jour)  \
# 0                                               0.20
# 1                                               0.01
# 2                                               0.01
# 3                                                NaN
# 4                                               0.02
#
#    Disponibilité de protéines en quantité (g/personne/jour)  \
# 0                                               0.77
# 1                                               0.02
# 2                                               0.03
# 3                                                NaN
# 4                                               0.05
#
#    Disponibilité intérieure  Exportations - Quantité  Importations - Quantité  \
# 0                      53.0                      NaN                      NaN
# 1                      41.0                      2.0                     40.0
# 2                       2.0                      NaN                      2.0
# 3                       0.0                      NaN                      0.0
# 4                      82.0                      NaN                     82.0
#
#    Nourriture  Pertes  Production  Semences  Traitement  Variation de stock
# 0        53.0     NaN        53.0       NaN         NaN                 NaN
# 1        39.0     2.0         3.0       NaN         NaN                 NaN
# 2         2.0     NaN         NaN       NaN         NaN                 NaN
# 3         0.0     NaN         NaN       NaN         NaN                 NaN
# 4        82.0     NaN         NaN       NaN         NaN                 NaN

# %%
# suppression des NaN
dispo_alimentaire = dispo_alimentaire.dropna()

# %%
aide_alimentaire = pd.read_csv('data/aide_alimentaire.csv')
aide_alimentaire.head()
# Out:
#   Pays bénéficiaire  Année              Produit  Valeur
# 0       Afghanistan   2013  Autres non-céréales     682
# 1       Afghanistan   2014  Autres non-céréales     335
# 2       Afghanistan   2013         Blé et Farin   39224
# 3       Afghanistan   2014         Blé et Farin   15160
# 4       Afghanistan   2013             Céréales   40504

# %%
aide_alimentaire.info()
print("-------------------------------")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1475 entries, 0 to 1474
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Pays bénéficiaire  1475 non-null   object
#  1   Année              1475 non-null   int64
#  2   Produit            1475 non-null   object
#  3   Valeur             1475 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 46.2+ KB
# -------------------------------

# %%
population = pd.read_csv('data/population.csv')
population.head()
# Out:
#           Zone  Année     Valeur
# 0  Afghanistan   2013  32269.589
# 1  Afghanistan   2014  33370.794
# 2  Afghanistan   2015  34413.603
# 3  Afghanistan   2016  35383.032
# 4  Afghanistan   2017  36296.113

# %%
population.info()
print("-------------------------------")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1416 entries, 0 to 1415
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Zone    1416 non-null   object
#  1   Année   1416 non-null   int64
#  2   Valeur  1416 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 33.3+ KB
# -------------------------------

# %%
sous_nutrition = pd.read_csv('data/sous_nutrition.csv')
sous_nutrition.head()
# Out:
#           Zone      Année Valeur
# 0  Afghanistan  2012-2014    8.6
# 1  Afghanistan  2013-2015    8.8
# 2  Afghanistan  2014-2016    8.9
# 3  Afghanistan  2015-2017    9.7
# 4  Afghanistan  2016-2018   10.5

# %%
sous_nutrition["Année"] = sous_nutrition["Année"].map({'2012-2014': 2013,
                                                       '2013-2015': 2014,
                                                       '2014-2016': 2015,
                                                       '2015-2017': 2016,
                                                       '2016-2018': 2017,
                                                       '2017-2019': 2018})

# %%
# suppression des NaN
sous_nutrition = sous_nutrition.dropna()

# %%
sous_nutrition['Valeur'] = sous_nutrition['Valeur'].astype(str)

# %%
sous_nutrition.head()
# Out:
#           Zone  Année Valeur
# 0  Afghanistan   2013    8.6
# 1  Afghanistan   2014    8.8
# 2  Afghanistan   2015    8.9
# 3  Afghanistan   2016    9.7
# 4  Afghanistan   2017   10.5

# %%
sous_nutrition.info()
print("-------------------------------")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 624 entries, 0 to 1199
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Zone    624 non-null    object
#  1   Année   624 non-null    int64
#  2   Valeur  624 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 19.5+ KB
# -------------------------------

# %%
# Changement des noms de colonnes

aide_alimentaire = aide_alimentaire.rename(columns = {'Pays bénéficiaire': 'Zone', 'Valeur': 'Quantité (en tonne)'})
sous_nutrition = sous_nutrition.rename(columns = {'Valeur': 'sous_nutrition (million)'})
population = population.rename(columns = {'Valeur': 'nb_population (millier)'})

# %%
def merge_année(année=str):
    aide_alimentaire["Année"] = aide_alimentaire["Année"].astype(str)
    d1 = aide_alimentaire[aide_alimentaire["Année"] == année]
    sous_nutrition["Année"] = sous_nutrition["Année"].astype(str)
    d2 = sous_nutrition[sous_nutrition["Année"] == année]
    population["Année"] = population["Année"].astype(str)
    d3 = population[population["Année"] == année]
    ano = d1.merge(d2, on = "Zone", how = "left")
    result = ano.merge(d3, on = "Zone", how = "left")
    result["nb_population (million)"] = round((result["nb_population (millier)"]/1000),2)
    result['rapport_nutritionnel (tonne/habitant)'] = round((result["Quantité (en tonne)"] / result["nb_population (million)"]),2)
    result = result.dropna()
    nutri = result.groupby("Zone", axis = 0).min()
    nutri = nutri.reset_index()
    fig, ax = plt.subplots(1,2, figsize = (12,8))
    sns.barplot(data = nutri.sort_values("rapport_nutritionnel (tonne/habitant)", ascending = False).head(5),\
                     y = "rapport_nutritionnel (tonne/habitant)", x = "Zone", ax = ax[0])

    plt.title('Top 5 des pays en ratio alimentaire')
    sns.barplot(data= nutri.sort_values("rapport_nutritionnel (tonne/habitant)", ascending = True).head(5),\
                     y = "rapport_nutritionnel (tonne/habitant)", x = "Zone", ax = ax[1])
    plt.title('Flop 5 des pays en ratio alimentaire')
    fig.show()
    return nutri

# %%
merge_année("2013")
# Out:
#                                           Zone Année_x              Produit  \
# 0                                  Afghanistan    2013  Autres non-céréales
# 1                                      Algérie    2013  Autres non-céréales
# 2                                       Angola    2013             Céréales
# 3                                   Bangladesh    2013         Blé et Farin
# 4                                 Burkina Faso    2013  Autres non-céréales
# 5                                        Bénin    2013  Autres non-céréales
# 6                                     Cambodge    2013  Autres non-céréales
# 7                                     Cameroun    2013  Autres non-céréales
# 8                                     Colombie    2013             Céréales
# 9                                        Congo    2013  Autres non-céréales
# 10                               Côte d'Ivoire    2013  Autres non-céréales
# 11                                 El Salvador    2013             Céréales
# 12                                      Gambie    2013             Céréales
# 13                                       Ghana    2013             Céréales
# 14                                   Guatemala    2013             Céréales
# 15                                     Géorgie    2013  Autres non-céréales
# 16                                       Haïti    2013  Autres non-céréales
# 17                                    Honduras    2013             Céréales
# 18              Iran (République islamique d')    2013             Céréales
# 19                                        Iraq    2013  Autres non-céréales
# 20                                    Jordanie    2013  Autres non-céréales
# 21                                       Kenya    2013         Blé et Farin
# 22                                Kirghizistan    2013         Blé et Farin
# 23                                     Lesotho    2013             Céréales
# 24                                       Liban    2013  Autres non-céréales
# 25                                     Libéria    2013  Autres non-céréales
# 26                                  Madagascar    2013  Autres non-céréales
# 27                                      Malawi    2013  Autres non-céréales
# 28                                        Mali    2013  Autres non-céréales
# 29                                  Mauritanie    2013  Autres non-céréales
# 30                                  Mozambique    2013             Céréales
# 31                                     Myanmar    2013             Céréales
# 32                                   Nicaragua    2013  Autres non-céréales
# 33                                       Népal    2013             Céréales
# 34                                    Pakistan    2013  Autres non-céréales
# 35                                 Philippines    2013  Autres non-céréales
# 36                                      Rwanda    2013             Céréales
# 37                      République dominicaine    2013  Autres non-céréales
# 38  République populaire démocratique de Corée    2013         Blé et Farin
# 39                 République-Unie de Tanzanie    2013         Blé et Farin
# 40                        Sao Tomé-et-Principe    2013             Céréales
# 41                                Sierra Leone    2013         BulgurFarEnt
# 42                                      Soudan    2013             Céréales
# 43                                   Sri Lanka    2013             Céréales
# 44                                     Sénégal    2013  Autres non-céréales
# 45                                       Tchad    2013  Autres non-céréales
# 46                                 Timor-Leste    2013             Céréales
# 47                                        Togo    2013  Autres non-céréales
# 48                                      Égypte    2013   Fruits secs, total
# 49                                    Équateur    2013             Céréales
# 50                                    Éthiopie    2013  Autres non-céréales
#
#     Quantité (en tonne) Année_y sous_nutrition (million) Année  \
# 0                    85    2013                      8.6  2013
# 1                   204    2013                      1.3  2013
# 2                  2500    2013                      7.6  2013
# 3                    81    2013                     21.7  2013
# 4                    10    2013                      3.1  2013
# 5                    45    2013                      0.8  2013
# 6                    50    2013                      2.1  2013
# 7                   117    2013                      1.5  2013
# 8                   138    2013                      3.9  2013
# 9                    18    2013                      1.4  2013
# 10                   67    2013                      4.8  2013
# 11                 1005    2013                      0.7  2013
# 12                  347    2013                      0.2  2013
# 13                  322    2013                      1.9  2013
# 14                 1189    2013                      2.9  2013
# 15                    1    2013                      0.2  2013
# 16                   17    2013                      5.1  2013
# 17                 2798    2013                      1.7  2013
# 18                   46    2013                      3.6  2013
# 19                    4    2013                      7.3  2013
# 20                    3    2013                      0.8  2013
# 21                   46    2013                     10.1  2013
# 22                   80    2013                      0.4  2013
# 23                   81    2013                      0.3  2013
# 24                    2    2013                      0.7  2013
# 25                    2    2013                      1.5  2013
# 26                    5    2013                      7.6  2013
# 27                   63    2013                      2.7  2013
# 28                  853    2013                      1.1  2013
# 29                   89    2013                      0.3  2013
# 30                  504    2013                      5.9  2013
# 31                  714    2013                      6.7  2013
# 32                  136    2013                      1.1  2013
# 33                   64    2013                      1.8  2013
# 34                    9    2013                     31.1  2013
# 35                  109    2013                     14.5  2013
# 36                  497    2013                      2.8  2013
# 37                   12    2013                      0.9  2013
# 38                  900    2013                     10.3  2013
# 39                  153    2013                     13.5  2013
# 40                   36    2013                     <0.1  2013
# 41                  240    2013                      2.2  2013
# 42                   46    2013                      5.9  2013
# 43                    1    2013                      1.8  2013
# 44                  332    2013                      1.4  2013
# 45                    0    2013                      4.9  2013
# 46                   22    2013                      0.4  2013
# 47                    2    2013                      1.5  2013
# 48                  561    2013                      4.4  2013
# 49                  103    2013                      2.3  2013
# 50                  170    2013                     26.2  2013
#
#     nb_population (millier)  nb_population (million)  \
# 0                 32269.589                    32.27
# 1                 38140.133                    38.14
# 2                 26015.781                    26.02
# 3                152761.418                   152.76
# 4                 17072.785                    17.07
# 5                 10004.591                    10.00
# 6                 15026.332                    15.03
# 7                 22077.294                    22.08
# 8                 46495.493                    46.50
# 9                  4622.762                     4.62
# 10                22087.504                    22.09
# 11                 6266.070                     6.27
# 12                 1963.712                     1.96
# 13                26607.645                    26.61
# 14                15595.816                    15.60
# 15                 4048.701                     4.05
# 16                10400.675                    10.40
# 17                 8798.521                     8.80
# 18                76481.961                    76.48
# 19                33157.050                    33.16
# 20                 8518.983                     8.52
# 21                45519.981                    45.52
# 22                 5731.303                     5.73
# 23                 2028.530                     2.03
# 24                 5913.022                     5.91
# 25                 4248.334                     4.25
# 26                22961.255                    22.96
# 27                15839.286                    15.84
# 28                16449.854                    16.45
# 29                 3817.494                     3.82
# 30                25560.755                    25.56
# 31                51852.468                    51.85
# 32                 6062.457                     6.06
# 33                26916.793                    26.92
# 34               191260.806                   191.26
# 35                98871.555                    98.87
# 36                10811.538                    10.81
# 37                10048.232                    10.05
# 38                24929.497                    24.93
# 39                48483.129                    48.48
# 40                  192.087                     0.19
# 41                 6863.981                     6.86
# 42                37072.550                    37.07
# 43                20663.046                    20.66
# 44                13782.424                    13.78
# 45                13220.433                    13.22
# 46                 1153.294                     1.15
# 47                 6954.722                     6.95
# 48                88404.646                    88.40
# 49                15707.474                    15.71
# 50                95385.798                    95.39
#
#     rapport_nutritionnel (tonne/habitant)
# 0                                    2.63
# 1                                    5.35
# 2                                   96.08
# 3                                    0.53
# 4                                    0.59
# 5                                    4.50
# 6                                    3.33
# 7                                    5.30
# 8                                    2.97
# 9                                    3.90
# 10                                   3.03
# 11                                 160.29
# 12                                 177.04
# 13                                  12.10
# 14                                  76.22
# 15                                   0.25
# 16                                   1.63
# 17                                 317.95
# 18                                   0.60
# 19                                   0.12
# 20                                   0.35
# 21                                   1.01
# 22                                  13.96
# 23                                  39.90
# 24                                   0.34
# 25                                   0.47
# 26                                   0.22
# 27                                   3.98
# 28                                  51.85
# 29                                  23.30
# 30                                  19.72
# 31                                  13.77
# 32                                  22.44
# 33                                   2.38
# 34                                   0.05
# 35                                   1.10
# 36                                  45.98
# 37                                   1.19
# 38                                  36.10
# 39                                   3.16
# 40                                 189.47
# 41                                  34.99
# 42                                   1.24
# 43                                   0.05
# 44                                  24.09
# 45                                   0.00
# 46                                  19.13
# 47                                   0.29
# 48                                   6.35
# 49                                   6.56
# 50                                   1.78
